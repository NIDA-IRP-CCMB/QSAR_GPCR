# %%
import sys, os
from pathlib import Path
home = str(Path.home())
core_dir = home+'/repositories/ai-x/core'
conf_dir = core_dir+"/keywords"
sys.path.insert(0, core_dir)
sys.path.insert(0, conf_dir)

from filters_dop import *
import re

def get_filtered_datasets(chembl_tsv_file, standard_type, target, assaydefinition, output_dir, base_name, broad=False,
                 before=False):
    "MAIN FUNCTION used in run_filters.py"
    # store data into "buffer" that's being *printed*
    with io.StringIO() as buf, redirect_stdout(buf):
        buffer = read_data(chembl_tsv_file, Verbose=True)
        buffer = filter_confidence(buffer, broad, Verbose=True)
        buffer = filter_assay_type(buffer, target=target, assaydefinition=assaydefinition, Verbose=True)
        if standard_type == "Ki":
            buffer = filter_affinity(buffer, Verbose=True, keepIC50=False, keepKi=True)
        if standard_type == "IC50":
            buffer = filter_affinity(buffer, Verbose=True, keepIC50=True, keepKi=False)
        buffer = filter_units(buffer, Verbose=True)
        buffer = filter_exact(buffer, Verbose=True)

        if "D2" in target or "D3" in target:
            if assaydefinition == "agonist":
                keys = ["agonist"]
            elif assaydefinition == "antagonist":
                keys = ["antagonist"]
            elif assaydefinition == "others":
                keys = ["others"]
            for key in keys:
                filtered_in, filtered_out = filter_assaydefinition(buffer, target, key, Verbose=False)
                buffer = filtered_in
            print("Number of compounds after Displacement Assay filter:", len(buffer))
            print("Number of compounds after removing testset 2 compounds:  n/a")

        buffer = filter_year(buffer, target, year=1990, Verbose=True)
        buffer = filter_bao_format(buffer, target, assaydefinition, Verbose=True)
        buffer = filter_selected(buffer, target, assaydefinition, Verbose=True)

        buffer = filter_small_sets(buffer, Verbose=True, threshold=4)
        buffer = filter_salts(buffer, conf_dir, Verbose=True)
        buffer = filter_elements(buffer, Verbose=True)
        buffer = filter_size(buffer, Verbose=True)
        buffer = filter_pchembl_values(buffer, Verbose=True, replace=True)
        buffer = filter_weirdos(buffer, Verbose=True)
        buffer = deduplicate_mols(buffer, Verbose=True)

        check_output_dir(output_dir, keep_old=False)
        write_smi_act_reg(buffer, base_name, output_dir, add_extra=False)
        write_smi_act_class(buffer, base_name, output_dir, inact_val=5.0, act_val=6.0, Verbose=True)

        # capture all the printed lines into 'buffer'
        output = buf.getvalue()

    with open(output_dir + '.log', 'w') as file:
        file.write(output.replace('\n\n', '\n'))

    return output
# Out:
# filters package has been imported!

# %%
# %%time
targets = ["D2", "D3"]
chembls = ["34"]
base_name = 'pubdata'
standard_types = ["Ki", "IC50"]
assaydefinitions = ["antagonist", "agonist"]
df = pd.DataFrame()
for chembl in chembls:
    df = pd.DataFrame()
    for target in targets:
        chembl_tsv_file = home+"/repositories/ai-DR/datasets/"+f"pgsql/all_pgsql/chembl{chembl}_{target}.tsv"
        for assaydefinition in assaydefinitions:
            for standard_type in standard_types:
                output_dir = f"new_datasets/C{chembl}/dataset_{target}_{assaydefinition}_{standard_type}"
                output = get_filtered_datasets(chembl_tsv_file, standard_type, target, assaydefinition, output_dir, base_name)
                ## if you want to save this to excel, we can make a df
                df = get_dataframe(output, df, target, standard_type, assaydefinition)
                print(f"Dataset created: chembl = {chembl}, target = {target}, assaydefinition = {assaydefinition},"
                      f" standard_type = {standard_type}")
                print(output)
                save_to_excel(df, chembl, "output_dir")
# Out:
# /home/wons2/repositories/ai-x/core/filters/write_smi_act_class.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   active_mols['pchembl_value_class'] = np.ones(len(active_mols), dtype=int)
# /home/wons2/repositories/ai-x/core/filters/write_smi_act_class.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inactive_mols['pchembl_value_class'] = np.zeros(len(inactive_mols), dtype=int)
# Dataset created: chembl = 34, target = D2, assaydefinition = antagonist, standard_type = Ki
# Number of pharmacological activity at starting:  31523
# Number of pharmacological activity after confidence score filter:  18682
# Number of compounds after assay type filter:  14010
# Number of pharmacological activity after Ki / IC50 / EC50 filter:  9284
# Number of pharmacological activity after standard units filter:  9229
# Number of pharmacological activity after activity relationship type fixes:  8350
# Number of compounds after Displacement Assay filter: 6530
# Number of compounds after removing testset 2 compounds:  n/a
# Number of compounds after 1990 year filter:  6460
# Number of compounds after BAO_FORMAT filter:  5625
# Number of compounds after patent & hand selecting (paper) filter:  5520
# Number of pharmacological activity after data set size filter:  5374
# Number of pharmacological activity after desalting pass:  5371
# Number of pharmacological activity after oddball element filter:  5361
# Number of pharmacological activity after molecular weight filter:  5212
# Number of pharmacological activity after pChEMBL value filter:  5212
# Number of pharmacological activity after edge case filter:  5212
# Number of pharmacological activity after deduplication pass:  3646
# Total number of molecules in training set:  3021
# Number of active molecules:  2916
# Number of inactive molecules:  105
#
# Dataset created: chembl = 34, target = D2, assaydefinition = antagonist, standard_type = IC50
# Number of pharmacological activity at starting:  31523
# Number of pharmacological activity after confidence score filter:  18682
# Number of compounds after assay type filter:  14010
# Number of pharmacological activity after Ki / IC50 / EC50 filter:  934
# Number of pharmacological activity after standard units filter:  934
# Number of pharmacological activity after activity relationship type fixes:  673
# Number of compounds after Displacement Assay filter: 473
# Number of compounds after removing testset 2 compounds:  n/a
# Number of compounds after 1990 year filter:  390
# Number of compounds after BAO_FORMAT filter:  325
# Number of compounds after patent & hand selecting (paper) filter:  325
# Number of pharmacological activity after data set size filter:  278
# Number of pharmacological activity after desalting pass:  278
# Number of pharmacological activity after oddball element filter:  278
# Number of pharmacological activity after molecular weight filter:  271
# Number of pharmacological activity after pChEMBL value filter:  271
# Number of pharmacological activity after edge case filter:  271
# Number of pharmacological activity after deduplication pass:  215
# Total number of molecules in training set:  182
# Number of active molecules:  169
# Number of inactive molecules:  13
#
# Dataset created: chembl = 34, target = D2, assaydefinition = agonist, standard_type = Ki
# Number of pharmacological activity at starting:  31523
# Number of pharmacological activity after confidence score filter:  18682
# Number of compounds after assay type filter:  18682
# Number of pharmacological activity after Ki / IC50 / EC50 filter:  9922
# Number of pharmacological activity after standard units filter:  9866
# Number of pharmacological activity after activity relationship type fixes:  8836
# Number of compounds after Displacement Assay filter: 592
# Number of compounds after removing testset 2 compounds:  n/a
# Number of compounds after 1990 year filter:  592
# Number of compounds after BAO_FORMAT filter:  592
# Number of compounds after patent & hand selecting (paper) filter:  568
# Number of pharmacological activity after data set size filter:  547
# Number of pharmacological activity after desalting pass:  547
# Number of pharmacological activity after oddball element filter:  547
# Number of pharmacological activity after molecular weight filter:  546
# Number of pharmacological activity after pChEMBL value filter:  546
# Number of pharmacological activity after edge case filter:  546
# Number of pharmacological activity after deduplication pass:  417
# Total number of molecules in training set:  373
# Number of active molecules:  367
# Number of inactive molecules:  6
#
# Dataset created: chembl = 34, target = D2, assaydefinition = agonist, standard_type = IC50
# Number of pharmacological activity at starting:  31523
# Number of pharmacological activity after confidence score filter:  18682
# Number of compounds after assay type filter:  18682
# Number of pharmacological activity after Ki / IC50 / EC50 filter:  1496
# Number of pharmacological activity after standard units filter:  1449
# Number of pharmacological activity after activity relationship type fixes:  1003
# Number of compounds after Displacement Assay filter: 457
# Number of compounds after removing testset 2 compounds:  n/a
# Number of compounds after 1990 year filter:  457
# Number of compounds after BAO_FORMAT filter:  457
# Number of compounds after patent & hand selecting (paper) filter:  457
# Number of pharmacological activity after data set size filter:  406
# Number of pharmacological activity after desalting pass:  406
# Number of pharmacological activity after oddball element filter:  406
# Number of pharmacological activity after molecular weight filter:  403
# Number of pharmacological activity after pChEMBL value filter:  403
# Number of pharmacological activity after edge case filter:  403
# Number of pharmacological activity after deduplication pass:  337
# Total number of molecules in training set:  274
# Number of active molecules:  250
# Number of inactive molecules:  24
#
# Dataset created: chembl = 34, target = D3, assaydefinition = antagonist, standard_type = Ki
# Number of pharmacological activity at starting:  15039
# Number of pharmacological activity after confidence score filter:  8581
# Number of compounds after assay type filter:  7059
# Number of pharmacological activity after Ki / IC50 / EC50 filter:  5137
# Number of pharmacological activity after standard units filter:  5130
# Number of pharmacological activity after activity relationship type fixes:  4825
# Number of compounds after Displacement Assay filter: 3568
# Number of compounds after removing testset 2 compounds:  n/a
# Number of compounds after 1990 year filter:  3568
# Number of compounds after BAO_FORMAT filter:  3568
# Number of compounds after patent & hand selecting (paper) filter:  3446
# Number of pharmacological activity after data set size filter:  3301
# Number of pharmacological activity after desalting pass:  3301
# Number of pharmacological activity after oddball element filter:  3297
# Number of pharmacological activity after molecular weight filter:  3246
# Number of pharmacological activity after pChEMBL value filter:  3246
# Number of pharmacological activity after edge case filter:  3246
# Number of pharmacological activity after deduplication pass:  2400
# Total number of molecules in training set:  2158
# Number of active molecules:  2113
# Number of inactive molecules:  45
#
# Dataset created: chembl = 34, target = D3, assaydefinition = antagonist, standard_type = IC50
# Number of pharmacological activity at starting:  15039
# Number of pharmacological activity after confidence score filter:  8581
# Number of compounds after assay type filter:  7059
# Number of pharmacological activity after Ki / IC50 / EC50 filter:  255
# Number of pharmacological activity after standard units filter:  244
# Number of pharmacological activity after activity relationship type fixes:  198
# Number of compounds after Displacement Assay filter: 145
# Number of compounds after removing testset 2 compounds:  n/a
# Number of compounds after 1990 year filter:  145
# Number of compounds after BAO_FORMAT filter:  145
# Number of compounds after patent & hand selecting (paper) filter:  145
# Number of pharmacological activity after data set size filter:  131
# Number of pharmacological activity after desalting pass:  131
# Number of pharmacological activity after oddball element filter:  131
# Number of pharmacological activity after molecular weight filter:  131
# Number of pharmacological activity after pChEMBL value filter:  131
# Number of pharmacological activity after edge case filter:  131
# Number of pharmacological activity after deduplication pass:  111
# Total number of molecules in training set:  100
# Number of active molecules:  100
# Number of inactive molecules:  0
# Dataset created: chembl = 34, target = D3, assaydefinition = agonist, standard_type = Ki
# Number of pharmacological activity at starting:  15039
# Number of pharmacological activity after confidence score filter:  8581
# Number of compounds after assay type filter:  8581
# Number of pharmacological activity after Ki / IC50 / EC50 filter:  5569
# Number of pharmacological activity after standard units filter:  5562
# Number of pharmacological activity after activity relationship type fixes:  5237
# Number of compounds after Displacement Assay filter: 749
# Number of compounds after removing testset 2 compounds:  n/a
# Number of compounds after 1990 year filter:  749
# Number of compounds after BAO_FORMAT filter:  749
# Number of compounds after patent & hand selecting (paper) filter:  746
# Number of pharmacological activity after data set size filter:  719
# Number of pharmacological activity after desalting pass:  718
# Number of pharmacological activity after oddball element filter:  718
# Number of pharmacological activity after molecular weight filter:  717
# Number of pharmacological activity after pChEMBL value filter:  717
# Number of pharmacological activity after edge case filter:  717
# Number of pharmacological activity after deduplication pass:  536
# Total number of molecules in training set:  499
# Number of active molecules:  495
# Number of inactive molecules:  4
#
# Dataset created: chembl = 34, target = D3, assaydefinition = agonist, standard_type = IC50
# Number of pharmacological activity at starting:  15039
# Number of pharmacological activity after confidence score filter:  8581
# Number of compounds after assay type filter:  8581
# Number of pharmacological activity after Ki / IC50 / EC50 filter:  362
# Number of pharmacological activity after standard units filter:  351
# Number of pharmacological activity after activity relationship type fixes:  304
# Number of compounds after Displacement Assay filter: 183
# Number of compounds after removing testset 2 compounds:  n/a
# Number of compounds after 1990 year filter:  183
# Number of compounds after BAO_FORMAT filter:  183
# Number of compounds after patent & hand selecting (paper) filter:  183
# Number of pharmacological activity after data set size filter:  163
# Number of pharmacological activity after desalting pass:  163
# Number of pharmacological activity after oddball element filter:  163
# Number of pharmacological activity after molecular weight filter:  160
# Number of pharmacological activity after pChEMBL value filter:  160
# Number of pharmacological activity after edge case filter:  160
# Number of pharmacological activity after deduplication pass:  124
# Total number of molecules in training set:  112
# Number of active molecules:  108
# Number of inactive molecules:  4
#
# CPU times: user 1min 53s, sys: 257 ms, total: 1min 53s
# Wall time: 1min 58s

# %%
df
# Out:
#                                                   0           1        2  \
#                                                  D2          D2       D2
# Starting data                                 31523       31523    31523
# After confidence score filter                 18682       18682    18682
# After assay type filter                       14010       14010    18682
#                                                  Ki        IC50       Ki
# After Ki / IC50 filter                         9284         934     9922
# After standard units filter                    9229         934     9866
# After activity relationship type fixes         8350         673     8836
#
#
#                                                  D2          D2       D2
#                                          antagonist  antagonist  agonist
#                                                  Ki        IC50       Ki
# After assay description filter                 6530         473      592
# Reserving hERG calibration compounds            n/a         n/a      n/a
# After year 1990 filter                         6460         390      592
# After bioassay ontology filter                 5625         325      592
# After patent and manual curation filter        5520         325      568
# After data set size filter                     5374         278      547
# Desalting pass                                 5371         278      547
# After oddball element filter                   5361         278      547
# After molecular weight filter                  5212         271      546
# After pChEMBL value filter                     5212         271      546
# After edge case filter                         5212         271      546
# After deduplication pass                       3646         215      417
# Excluding 5-6 pKi/pIC50                        3021         182      373
# Binders                                        2916         169      367
# Non-binders                                     105          13        6
#
#                                                3           4           5  \
#                                               D2          D3          D3
# Starting data                              31523       15039       15039
# After confidence score filter              18682        8581        8581
# After assay type filter                    18682        7059        7059
#                                             IC50          Ki        IC50
# After Ki / IC50 filter                      1496        5137         255
# After standard units filter                 1449        5130         244
# After activity relationship type fixes      1003        4825         198
#
#
#                                               D2          D3          D3
#                                          agonist  antagonist  antagonist
#                                             IC50          Ki        IC50
# After assay description filter               457        3568         145
# Reserving hERG calibration compounds         n/a         n/a         n/a
# After year 1990 filter                       457        3568         145
# After bioassay ontology filter               457        3568         145
# After patent and manual curation filter      457        3446         145
# After data set size filter                   406        3301         131
# Desalting pass                               406        3301         131
# After oddball element filter                 406        3297         131
# After molecular weight filter                403        3246         131
# After pChEMBL value filter                   403        3246         131
# After edge case filter                       403        3246         131
# After deduplication pass                     337        2400         111
# Excluding 5-6 pKi/pIC50                      274        2158         100
# Binders                                      250        2113         100
# Non-binders                                   24          45           0
#
#                                                6        7
#                                               D3       D3
# Starting data                              15039    15039
# After confidence score filter               8581     8581
# After assay type filter                     8581     8581
#                                               Ki     IC50
# After Ki / IC50 filter                      5569      362
# After standard units filter                 5562      351
# After activity relationship type fixes      5237      304
#
#
#                                               D3       D3
#                                          agonist  agonist
#                                               Ki     IC50
# After assay description filter               749      183
# Reserving hERG calibration compounds         n/a      n/a
# After year 1990 filter                       749      183
# After bioassay ontology filter               749      183
# After patent and manual curation filter      746      183
# After data set size filter                   719      163
# Desalting pass                               718      163
# After oddball element filter                 718      163
# After molecular weight filter                717      160
# After pChEMBL value filter                   717      160
# After edge case filter                       717      160
# After deduplication pass                     536      124
# Excluding 5-6 pKi/pIC50                      499      112
# Binders                                      495      108
# Non-binders                                    4        4
