# %%
import sys, os
from pathlib import Path
home = str(Path.home())
core_dir = home+'/repositories/ai-DR/core'
sys.path.insert(0, core_dir)

from dataset_characteristics import *

# %%
color_IC = "grey"

# %%
selectivity = False
ls_colors = [color_IC, "navy"]
datasets = ["dataset_D2_antagonist_IC50", "dataset_D2_antagonist_Ki"]
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="")
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="output_dir/distribution_D2_antagonist.png")

# %%
ls_colors = [color_IC, "firebrick"]
datasets = ["dataset_D3_antagonist_IC50", "dataset_D3_antagonist_Ki"]
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="")
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="output_dir/distribution_D3_antagonist.png")

# %%
ls_colors = [color_IC, "deepskyblue"]
datasets = ["dataset_D2_overlap_antagonist_IC50", "dataset_D2_overlap_antagonist_Ki"]
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="")
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="output_dir/distribution_D2_overlap_antagonist.png")

# %%
ls_colors = [color_IC, "lightcoral"]
datasets = ["dataset_D3_overlap_antagonist_IC50", "dataset_D3_overlap_antagonist_Ki"]
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="")
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="output_dir/distribution_D3_overlap_antagonist.png")

# %%
ls_colors = [color_IC, "cornflowerblue"]
datasets = ["dataset_D2_only_antagonist_IC50", "dataset_D2_only_antagonist_Ki"]
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="")
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="output_dir/distribution_D2_only_antagonist.png")

# %%
ls_colors = [color_IC, "red"]
datasets = ["dataset_D3_only_antagonist_IC50", "dataset_D3_only_antagonist_Ki"]
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="")
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="output_dir/distribution_D3_only_antagonist.png")

# %%
selectivity = True
ls_colors = [color_IC, "magenta"]
datasets = ["dataset__ratio_D2_antagonist_IC50_D3_antagonist_IC50", "dataset__ratio_D2_antagonist_Ki_D3_antagonist_Ki"]
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="")
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png = "output_dir/distribution_D3_selective_antagonist.png")

# %%
selectivity = False
ls_colors = [color_IC, "black"]
datasets = ["dataset_D2_agonist_IC50", "dataset_D2_agonist_Ki"]
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="")
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="output_dir/distribution_D2_agonist.png")

# %%
selectivity = False
ls_colors = [color_IC, "black"]
datasets = ["dataset_D3_agonist_IC50", "dataset_D3_agonist_Ki"]
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="")
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="output_dir/distribution_D3_agonist.png")
