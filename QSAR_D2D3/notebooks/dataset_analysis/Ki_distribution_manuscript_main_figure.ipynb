# %%
import sys, os
from pathlib import Path
home = str(Path.home())
core_dir = home+'/repositories/ai-DR/core'
sys.path.insert(0, core_dir)

from dataset_characteristics import *

# %%
selectivity = False
ls_colors = ["navy", "deepskyblue", "firebrick", "lightcoral"]
datasets = ["dataset_D2_antagonist_Ki", "dataset_D3_antagonist_Ki", 
            "dataset_D2_overlap_antagonist_Ki", "dataset_D3_overlap_antagonist_Ki"]
datasets = sorted(datasets)
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="")
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="output_dir/Figure1_D2_D3_Ki.png")

# %%
selectivity = True
ls_colors = ["magenta"]
datasets = ["dataset__ratio_D2_antagonist_Ki_D3_antagonist_Ki"]
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png="")
plot_gaussian_distribution_mean(datasets, ls_colors, selectivity = selectivity, save2png = "output_dir/Figure1_D3_selective.png")
