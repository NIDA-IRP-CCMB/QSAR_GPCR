# %%
import sys, os
from pathlib import Path
home = str(Path.home())
py_dir = home+'/repositories/ai-x/core/parameter_analysis'
sys.path.insert(0, py_dir)
from parameter_analysis import *

modeldir = home+"/repositories/ai-DR/models/parameter_analysis/models4"
df = get_data(modeldir)
# Out:
# Sample of 7000

# %%
parameter = "epochs"
save2png = f"output_dir/time_{parameter}.png"
color = "skyblue"

parameter_time(df, parameter, color, save2png)
parameter_time(df, parameter, color, save2png = "")

# %%
parameter = "hidden_layers"
save2png = f"output_dir/time_{parameter}.png"
color = "orange"

parameter_time(df, parameter, color, save2png)
parameter_time(df, parameter, color, save2png = "")

# %%
parameter = "neurons"
save2png = f"output_dir/time_{parameter}.png"
color = "springgreen"

parameter_time(df, parameter, color, save2png)
parameter_time(df, parameter, color, save2png = "")

# %%
parameter = "learning_rate"
save2png = f"output_dir/time_{parameter}.png"
color = "gold"

parameter_time(df, parameter, color, save2png)
parameter_time(df, parameter, color, save2png = "")

# %%
parameter = "batch_size"
save2png = f"output_dir/time_{parameter}.png"
color = "mediumorchid"

parameter_time(df, parameter, color, save2png)
parameter_time(df, parameter, color, save2png = "")

# %%
parameter = "dropout"
save2png = f"output_dir/time_{parameter}.png"
color = "lightcoral"

parameter_time(df, parameter, color, save2png)
parameter_time(df, parameter, color, save2png = "")
