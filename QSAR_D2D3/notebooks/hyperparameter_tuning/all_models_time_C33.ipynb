# %%
import sys, os
from pathlib import Path
home = str(Path.home())
py_dir = home+'/repositories/ai-x/core/parameter_analysis'
sys.path.insert(0, py_dir)
from parameter_analysis import *

core_dir = home+'/repositories/ai-x/core'
sys.path.insert(0, core_dir)
from misc import check_output_dir
output_dir = "output_dir"
check_output_dir(output_dir, keep_old = False)


modeldir = home+"/repositories/ai-DR/models/parameter_analysis/models4"
df = get_data(modeldir)
df_feasible_324 = get_feasible_df(modeldir)
df_feasible_162 = df_feasible_324[df_feasible_324["dropout"] == 0.0]
# Out:
# Sample of 7000
#
# feasible df is size  324

# %%
scoring = "R2"
save2png = f"{output_dir}/Figure2_R2.png"
get_total_time_plot(scoring, df, df_feasible_324, save2png=save2png)
get_total_time_plot(scoring, df, df_feasible_324, save2png="")
# Out:
# df_subset in red zone:  288 324
# df_subset in red zone:  288 324

# %%
scoring = "RMSE"
save2png = f"{output_dir}/Figure2_RMSE.png"
get_total_time_plot(scoring, df, df_feasible_324, save2png=save2png)
get_total_time_plot(scoring, df, df_feasible_324, save2png="")
# Out:
# df_subset in red zone:  318 324
# df_subset in red zone:  318 324

# %%
scoring = "Rp"
save2png = f"{output_dir}/Figure2_Rp.png"
get_total_time_plot(scoring, df, df_feasible_324, save2png=save2png)
get_total_time_plot(scoring, df, df_feasible_324, save2png="")
# Out:
# df_subset in red zone:  284 324
# df_subset in red zone:  284 324

# %%
scoring = "Rs"
save2png = f"{output_dir}/Figure2_Rp.png"
get_total_time_plot(scoring, df, df_feasible_324, save2png=save2png)
get_total_time_plot(scoring, df, df_feasible_324, save2png="")
# Out:
# df_subset in red zone:  256 324
# df_subset in red zone:  256 324
