# %%
import sys, os
from pathlib import Path
home = str(Path.home())
core_dir = home+'/repositories/ai-x/core'
sys.path.insert(0, core_dir)


from draw_Pharm2D import *
from shap_analysis import *

# col_name = "SHAP Percent"
col_name = "SHAP Values Mean"
output_dir = "output_dir_shap"

# %% [markdown]
# # Ph2D

# %%
xfontsize = 20
ylim = [0, 0.25] 
y_tick_interval = 0.05

# %%
# XGB 
# datadir = "/home/wons2/repositories/ai-DR/models/selectivity_D2D3/selectivity_models/models_C33_0/"
datadir = "/data/Shilab/scratch/sjwon3789/selectivity_models/models_C33_0/"
models = ["models_D2", "models_D3", "models__ratio_D2D3"]
method = "xgb"
bar_color = "lightcoral"

for model in models:
    if model == "models__ratio_D2D3":
        title = f"D3-selective, {method.upper()}"
    else:
        s = model.replace("models_", "")
        title = f"{s}: {method.upper()}" 

    df_with_Ph2D, df_without_Ph2D = shap_analysis(datadir, method, model)
    print(model)
    print(sum(df_with_Ph2D["SHAP Percent"]))
    print(sum(df_without_Ph2D["SHAP Percent"]))

    save2png = f"{output_dir}/features_{model}_{method}_1.png"
    plot_shap(df_with_Ph2D, col_name, title + " (Ph2D Features)", ylim, y_tick_interval, xfontsize, bar_color, save2png)
    plot_shap(df_with_Ph2D, col_name, title + " (Ph2D Features)", ylim, y_tick_interval, xfontsize, bar_color, save2png="")


#     save2png = f"output_dir/features_{model}_{method}_2.png"
#     plot_shap(df_without_Ph2D, title + " (Ph2D Features)", ylim, save2png)
# Out:
# models_D2
# 0.7715110928359231
# 0.22848890716407833
# models_D3
# 0.6600450504972089
# 0.3399549495027908
# models__ratio_D2D3
# 0.6346883293866316
# 0.3653116706133662

# %%
# RF
# datadir = "/home/wons2/repositories/ai-DR/models/selectivity_D2D3/selectivity_models/models_C33_0/"
models = ["models_D2", "models_D3", "models__ratio_D2D3"]
method = "rf"
bar_color = "deepskyblue"
# ylim = [0, 0.20] 
# y_tick_interval = 0.05

for model in models:
    if model == "models__ratio_D2D3":
        title = f"D3-selective, {method.upper()}"
    else:
        s = model.replace("models_", "")
        title = f"{s}: {method.upper()}" 

    df_with_Ph2D, df_without_Ph2D = shap_analysis(datadir, method, model)
    print(model)
    print(sum(df_with_Ph2D["SHAP Percent"]))
    print(sum(df_without_Ph2D["SHAP Percent"]))

    save2png = f"{output_dir}/features_{model}_{method}_1.png"
    plot_shap(df_with_Ph2D, col_name, title + " (Ph2D Features)", ylim, y_tick_interval, xfontsize, bar_color, save2png)
    plot_shap(df_with_Ph2D, col_name, title + " (Ph2D Features)", ylim, y_tick_interval, xfontsize, bar_color, save2png="")

#     save2png = f"output_dir/features_{model}_{method}_2.png"
#     plot_shap(df_without_Ph2D, title + " (Ph2D Features)", ylim, save2png)
# Out:
# models_D2
# 0.801594492565244
# 0.1984055074347554
# models_D3
# 0.6319343489998396
# 0.36806565100016136
# models__ratio_D2D3
# 0.6988075923130079
# 0.30119240768699057

# %%
# DNN
# datadir = "/home/wons2/Shilab/sjwon3789/selectivity_models_C33_v19/models_C33_0/"
models = ["models_D2", "models_D3", "models__ratio_D2D3"]
#models_D3
method = "dnn"
bar_color = "mediumseagreen"
# ylim = [0, 0.003] 
# y_tick_interval = 0.001

for model in models:
    if model == "models__ratio_D2D3":
        title = f"D3-selective, {method.upper()}"
    else:
        s = model.replace("models_", "")
        title = f"{s}: {method.upper()}" 

    df_with_Ph2D, df_without_Ph2D = shap_analysis(datadir, method, model)
    print(model)
    print(sum(df_with_Ph2D["SHAP Percent"]))
    print(sum(df_without_Ph2D["SHAP Percent"]))

    save2png = f"{output_dir}/features_{model}_{method}_1.png"
    plot_shap(df_with_Ph2D, col_name, title + " (Ph2D Features)", ylim, y_tick_interval, xfontsize, bar_color, save2png)
    plot_shap(df_with_Ph2D, col_name, title + " (Ph2D Features)", ylim, y_tick_interval, xfontsize, bar_color, save2png="")

    #     save2png = f"output_dir/features_{model}_{method}_2.png"
#     plot_shap(df_without_Ph2D, title + " (Ph2D Features)", ylim, save2png)
# Out:
# models_D2
# 0.7712752040378313
# 0.22872479596216821
# models_D3
# 0.7432980573499127
# 0.2567019426500877
# models__ratio_D2D3
# 0.7899319067934811
# 0.21006809320651768

# %%
# DNN
# datadir = "/home/wons2/Shilab/sjwon3789/selectivity_models_C33_v19/models_C33_0/"
method = "dnn"
model = "models_D2"
model = "models_D3"
model = "models__ratio_D2D3"
#models_D3
df_with_Ph2D, df_without_Ph2D = shap_analysis(datadir, method, model)
df_without_Ph2D.head(10)
# Out:
#             Features                                        Description  \
# 0           fr_amide                                   Number of amides
# 1         SlogP_VSA8      MOE logP VSA Descriptor 8 ( 0.25 <= x <  0...
# 2          PEOE_VSA3      MOE Charge VSA Descriptor 3 (-0.25 <= x < ...
# 3  NumRotatableBonds                          Number of Rotatable Bonds
# 4         PEOE_VSA13      MOE Charge VSA Descriptor 13 ( 0.25 <= x <...
# 5        EState_VSA4       EState VSA Descriptor 4 ( 0.72 <= x <  1.17)
# 6          PEOE_VSA4      MOE Charge VSA Descriptor 4 (-0.20 <= x < ...
# 7         SlogP_VSA4      MOE logP VSA Descriptor 4 ( 0.00 <= x <  0...
# 8   MinPartialCharge                 MinPartialCharge(mol, force=False)
# 9  fr_Ndealkylation2      Number of tert-alicyclic amines (no hetero...
#
#    SHAP Values Mean  SHAP Values StdDev  SHAP Percent
# 0          0.021750            0.010996      0.004177
# 1          0.021337            0.006527      0.004097
# ...

# %% [markdown]
# # Non-Ph2D

# %%
xfontsize = 14
ylim = [0, 0.25] 
y_tick_interval = 0.05

# %%
# datadir = "/home/wons2/repositories/ai-DR/models/selectivity_D2D3/selectivity_models/models_C33_0/"
models = ["models_D2", "models_D3", "models__ratio_D2D3"]
method = "xgb"
bar_color = "lightcoral"
# ylim = [0, 0.17] 
# y_tick_interval = 0.01

for model in models:
    if model == "models__ratio_D2D3":
        title = f"D3-selective, {method.upper()}"
    else:
        s = model.replace("models_", "")
        title = f"{s}: {method.upper()}" 

    df_with_Ph2D, df_without_Ph2D = shap_analysis(datadir, method, model)

    save2png = f"{output_dir}/features_{model}_{method}_2.png"
    plot_shap(df_without_Ph2D, col_name, title + " (Ph2D Features)", ylim, y_tick_interval, xfontsize, bar_color, save2png)
    plot_shap(df_without_Ph2D, col_name, title + " (Ph2D Features)", ylim, y_tick_interval, xfontsize, bar_color, save2png="")

# %%
# datadir = "/home/wons2/repositories/ai-DR/models/selectivity_D2D3/selectivity_models/models_C33_0/"
models = ["models_D2", "models_D3", "models__ratio_D2D3"]
method = "rf"
bar_color = "deepskyblue"
# ylim = [0, 0.35] 
# y_tick_interval = 0.05

for model in models:
    if model == "models__ratio_D2D3":
        title = f"D3-selective, {method.upper()}"
    else:
        s = model.replace("models_", "")
        title = f"{s}: {method.upper()}" 

    df_with_Ph2D, df_without_Ph2D = shap_analysis(datadir, method, model)

    save2png = f"{output_dir}/features_{model}_{method}_2.png"
    plot_shap(df_without_Ph2D, col_name, title + " (Ph2D Features)", ylim, y_tick_interval, xfontsize, bar_color, save2png)
    plot_shap(df_without_Ph2D, col_name, title + " (Ph2D Features)", ylim, y_tick_interval, xfontsize, bar_color, save2png="")

# %%
#datadir = "/home/wons2/repositories/ai-DR/models/selectivity_D2D3/selectivity_models/models_C33_0/"
# datadir = "/home/wons2/Shilab/sjwon3789/selectivity_models_C33_v19/models_C33_0/"
models = ["models_D2", "models_D3", "models__ratio_D2D3"]
method = "dnn"
bar_color = "mediumseagreen"
# ylim = [0, 0.26] 
# y_tick_interval = 0.05

for model in models:
    if model == "models__ratio_D2D3":
        title = f"D3-selective, {method.upper()}"
    else:
        s = model.replace("models_", "")
        title = f"{s}: {method.upper()}" 

    df_with_Ph2D, df_without_Ph2D = shap_analysis(datadir, method, model)

    save2png = f"{output_dir}/features_{model}_{method}_2.png"
    plot_shap(df_without_Ph2D, col_name, title + " (Non-Ph2D Features)", ylim, y_tick_interval, xfontsize, bar_color, save2png)
    plot_shap(df_without_Ph2D, col_name, title + " (Non-Ph2D Features)", ylim, y_tick_interval, xfontsize, bar_color, save2png="")
