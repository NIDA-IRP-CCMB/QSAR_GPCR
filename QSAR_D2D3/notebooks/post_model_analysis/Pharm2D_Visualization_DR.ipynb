# %%
import sys, os
from pathlib import Path
home = str(Path.home())
core_dir = home+'/repositories/ai-x/core'
sys.path.insert(0, core_dir)

from draw_Pharm2D import *
from feature_distribution import *


def check_output_dir(output_dir):
    """Create the output directory if it doesn't exist."""
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"Directory '{output_dir}' created.")
    else:
        print(f"Directory '{output_dir}' already exists.")
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
# %matplotlib inline
datadir = "~/repositories/ai-DR/models/selectivity_D2D3/selectivity_datasets/C33_0"
filenames = [f"{datadir}/dataset_D2_antagonist_Ki/pubdata0", f"{datadir}/dataset_D3_antagonist_Ki/pubdata0"]

# %%
# If saving svg files
# output_dir = "output_dir/Ph2D_165"
#feature = "Ph2D_14150"
#feature = "Ph2D_20761"
check_output_dir("output_dir_chembls")
feature = "Ph2D_16088"
output_dir = f"output_dir_chembls/{feature}"
save = True
verbose = False

# CHEMBL3935692 - cluster 15
# CHEMBL196476 - cluster 7 
# CHEMBL4469584 - cluster 6
# CHEMBL3125989 - cluster 4
# Out:
# Directory 'output_dir_chembls' created.

# %%
CHEMBL_ID = 3935692
mol = convert_id_to_mol(CHEMBL_ID, filenames)
Draw_Pharm2D(mol, CHEMBL_ID, feature, output_dir, save=save, verbose = verbose, rot_x=180, rot_y=0,rot_z=0)

# %%
CHEMBL_ID = 196476
mol = convert_id_to_mol(CHEMBL_ID, filenames)
Draw_Pharm2D(mol, CHEMBL_ID, feature, output_dir, save=save, verbose = verbose, rot_x=180, rot_y=0,rot_z=0)
