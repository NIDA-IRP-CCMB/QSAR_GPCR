# %%
import sys, os
from pathlib import Path
home = str(Path.home())
core_dir = home+'/repositories/ai-x/core'
sys.path.insert(0, core_dir)

from feature_distribution import *
import pandas as pd

output_dir = "output_dir_consensus"

# %%
# %%time
df_d2 = get_training_df("D2")
df_d3 = get_training_df("D3")
df_d2d3 = get_training_df("D2D3")
# Out:
# The file train_descs_D2.pkl exists.
# The file train_descs_D3.pkl exists.
# The file train_descs_D2D3.pkl exists.
# CPU times: user 494 ms, sys: 386 ms, total: 880 ms
# Wall time: 1.15 s

# %%
# %matplotlib inline
y_tick_interval = 1
xlim = [4, 11]
ylim = [15, 25]
feature = "Kappa1"

save2png = f"{output_dir}/Non_Ph2D_D3_"+feature+".png"
plot_NonPh2D_hist(df_d3, feature, xlim, ylim, y_tick_interval, save2png = "")
plot_NonPh2D_hist(df_d3, feature, xlim, ylim, y_tick_interval, save2png = save2png)
# Out:
# Feature Kappa1 Min 7.326147454014241 Max 35.26758564423745

# %%
# %matplotlib inline
y_tick_interval = 1
xlim = [4, 11]
ylim = [0, 10]
feature = "Phi"

save2png = f"{output_dir}/Non_Ph2D_D3_"+feature+".png"
plot_NonPh2D_hist(df_d3, feature, xlim, ylim, y_tick_interval, save2png = "")
plot_NonPh2D_hist(df_d3, feature, xlim, ylim, y_tick_interval, save2png = save2png)
# Out:
# Feature Phi Min 1.3852302656739055 Max 14.107129019578801

# %%
# %matplotlib inline
y_tick_interval = 1
xlim = [-4, 4]
ylim = [0, 30]
feature = "SlogP_VSA8"

save2png = f""
plot_NonPh2D_hist(df_d2d3, feature, xlim, ylim, y_tick_interval, save2png = "")
plot_NonPh2D_hist(df_d2d3, feature, xlim, ylim, y_tick_interval, save2png = save2png)
# Out:
# Feature SlogP_VSA8 Min 0.0 Max 44.19229467900206
# Feature SlogP_VSA8 Min 0.0 Max 44.19229467900206

# %%
# %matplotlib inline
y_tick_interval = 1
xlim = [4, 11]
ylim = [0, 10]
feature = "VSA_EState7"

save2png = f""
plot_NonPh2D_hist(df_d2, feature, xlim, ylim, y_tick_interval, save2png = "")
plot_NonPh2D_hist(df_d2, feature, xlim, ylim, y_tick_interval, save2png = save2png)
# Out:
# Feature VSA_EState7 Min -5.854703085680338 Max 29.689898767507987
# Feature VSA_EState7 Min -5.854703085680338 Max 29.689898767507987
