# %%
import sys
from pathlib import Path
home = str(Path.home())
core_dir = home+'/repositories/ai-x/core'
sys.path.insert(0, core_dir)
core_dir = home+'/repositories/ai-DR/core'
sys.path.insert(0, core_dir)

datadir = home+"/repositories/ai-DR/models/dataset_quality_XGB"
output_dir = "output_dir"

from misc import check_output_dir
check_output_dir(output_dir, keep_old = False)

from dataset_quality import *

# %%
methods = ["xgb", "rf"]
df = get_internal_dataset_quality(datadir, methods)
df
# Out:
#    Dataset Version          model method  n_models     Rp(mean)  Rp(max)  \
# 0     models_C33_1  D2_antagonist    xgb        10  0.81 (0.02)     0.81
# 1     models_C33_1  D2_antagonist     rf        10  0.81 (0.01)     0.81
# 2     models_C33_1  D3_antagonist    xgb        10  0.83 (0.03)     0.83
# 3     models_C33_1  D3_antagonist     rf        10  0.83 (0.02)     0.83
# 4     models_C33_2  D2_antagonist    xgb        10   0.8 (0.01)     0.80
# 5     models_C33_2  D2_antagonist     rf        10   0.8 (0.01)     0.80
# 6     models_C33_2  D3_antagonist    xgb        10  0.83 (0.02)     0.83
# 7     models_C33_2  D3_antagonist     rf        10  0.83 (0.01)     0.83
# 8     models_C33_3  D2_antagonist    xgb        10  0.81 (0.01)     0.81
# 9     models_C33_3  D2_antagonist     rf        10  0.81 (0.02)     0.81
# 10    models_C33_3  D3_antagonist    xgb        10  0.82 (0.01)     0.82
# 11    models_C33_3  D3_antagonist     rf        10  0.82 (0.02)     0.82
# ...

# %%
_df = df[df["model"]=="D2_antagonist"]
_df.to_csv("output_dir/dataset_quality_D2_antagonist.csv")
_df
# Out:
#    Dataset Version          model method  n_models     Rp(mean)  Rp(max)  \
# 0     models_C33_1  D2_antagonist    xgb        10  0.81 (0.02)     0.81
# 1     models_C33_1  D2_antagonist     rf        10  0.81 (0.01)     0.81
# 4     models_C33_2  D2_antagonist    xgb        10   0.8 (0.01)     0.80
# 5     models_C33_2  D2_antagonist     rf        10   0.8 (0.01)     0.80
# 8     models_C33_3  D2_antagonist    xgb        10  0.81 (0.01)     0.81
# 9     models_C33_3  D2_antagonist     rf        10  0.81 (0.02)     0.81
# 12    models_C33_4  D2_antagonist    xgb        10  0.81 (0.02)     0.81
# 13    models_C33_4  D2_antagonist     rf        10   0.8 (0.02)     0.80
# 16    models_C33_5  D2_antagonist    xgb        10  0.81 (0.01)     0.81
# 17    models_C33_5  D2_antagonist     rf        10  0.81 (0.01)     0.81
# 20    models_C33_6  D2_antagonist    xgb        10  0.83 (0.01)     0.83
# 21    models_C33_6  D2_antagonist     rf        10  0.82 (0.01)     0.82
#
# ...

# %%
_df = df[df["model"]=="D3_antagonist"]
_df.to_csv("output_dir/dataset_quality_D3_antagonist.csv")
_df
# Out:
#    Dataset Version          model method  n_models     Rp(mean)  Rp(max)  \
# 2     models_C33_1  D3_antagonist    xgb        10  0.83 (0.03)     0.83
# 3     models_C33_1  D3_antagonist     rf        10  0.83 (0.02)     0.83
# 6     models_C33_2  D3_antagonist    xgb        10  0.83 (0.02)     0.83
# 7     models_C33_2  D3_antagonist     rf        10  0.83 (0.01)     0.83
# 10    models_C33_3  D3_antagonist    xgb        10  0.82 (0.01)     0.82
# 11    models_C33_3  D3_antagonist     rf        10  0.82 (0.02)     0.82
#
#        Rs(mean)  Rs(max)     R2(mean)  R2(max)   RMSE(mean)  RMSE(min)
# 2   0.82 (0.03)     0.82  0.68 (0.04)     0.68  0.66 (0.05)       0.59
# 3   0.83 (0.02)     0.83  0.69 (0.03)     0.69  0.65 (0.04)       0.61
# 6   0.84 (0.02)     0.84  0.69 (0.03)     0.69  0.66 (0.03)       0.62
# 7   0.84 (0.02)     0.84  0.69 (0.02)     0.69  0.66 (0.02)       0.64
# 10  0.82 (0.01)     0.82  0.68 (0.02)     0.68  0.71 (0.02)       0.69
# ...
